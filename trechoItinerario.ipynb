# %%
from utilities.download import download_and_read_json_xz

# Example usage
url = "http://dadosabertos.c3sl.ufpr.br/curitibaurbs/2023_11_25_trechosItinerarios.json.xz"
df = download_and_read_json_xz(url)

# %%
df
# Out:
#      COD_LINHA               NOME_LINHA  COD_CATEGORIA NOME_CATEGORIA  \
# 0          616  PORTAO / STA.BERNADETHE              1    ALIMENTADOR
# 1          616  PORTAO / STA.BERNADETHE              1    ALIMENTADOR
# 2          616  PORTAO / STA.BERNADETHE              1    ALIMENTADOR
# 3          616  PORTAO / STA.BERNADETHE              1    ALIMENTADOR
# 4          631        PIRATINI / BR-476              1    ALIMENTADOR
# ...        ...                      ...            ...            ...
# 1414       642                GANCHINHO              1    ALIMENTADOR
# 1415       309          MAD. CENTENÁRIO             15    MADRUGUEIRO
# 1416       309          MAD. CENTENÁRIO             15    MADRUGUEIRO
# 1417       469       CENTRO POLITÉCNICO              5   LINHA DIRETA
# 1418       469       CENTRO POLITÉCNICO              5   LINHA DIRETA
#
#       COD_EMPRESA      NOME_EMPRESA  COD_PTO_PARADA_TH  \
# 0              11  SORRISO/PIONEIRO               1192
# 1              11  SORRISO/PIONEIRO               1193
# 2              11  SORRISO/PIONEIRO               1191
# 3              11  SORRISO/PIONEIRO               1190
# 4              11  SORRISO/PIONEIRO                872
# ...           ...               ...                ...
# 1414           11  SORRISO/PIONEIRO                869
# 1415            5      CCD/PIONEIRO                672
# 1416            5      CCD/PIONEIRO                672
# 1417            5      CCD/PIONEIRO                511
# 1418            5      CCD/PIONEIRO                361
#
#                      NOME_PTO_PARADA_TH NOME_PTO_ABREVIADO  SEQ_PTO_ITI_TH  \
# 0     TERMINAL PORTAO (T.FANNY L.VERDE)       PORTAO/FANNY            5014
# 1        ESTACAO TUBO FANNY(LINHA VERDE         FANNY/L.VE            5015
# 2           ESTACAO TUBO STA.BERNADETHE         S.BERNADET            5013
# 3     TERMINAL PORTAO (T.STA.BERNADETH)      PORTAO/STA.BE            5012
# 4            TERMINAL PINHEIRINHO-BR476         PINH/BR476            2285
# ...                                 ...                ...             ...
# 1414               TERMINAL PINHEIRINHO         PINHEIRINH            6456
# 1415                  PRACA RUI BARBOSA          R.BARBOSA            6491
# 1416                  PRACA RUI BARBOSA          R.BARBOSA            6491
# 1417            ESTACAO TUBO PREFEITURA         T.PREFEIT.            6665
# 1418                 CENTRO POLITECNICO         C.POLITEC.            2176
#
#       ...  COD_PTO_TRECHO_A SEQ_PONTO_TRECHO_A COD_PTO_TRECHO_B  \
# 0     ...              1192               5014             1193
# 1     ...              1193               5015             1190
# 2     ...              1191               5013             1192
# 3     ...              1190               5012             1191
# 4     ...               872               2285              873
# ...   ...               ...                ...              ...
# 1414  ...               869               6456              114
# 1415  ...               672               6491              672
# 1416  ...               672               6491              837
# 1417  ...               511               6665              361
# 1418  ...               361               2176              511
#
#       SEQ_PONTO_TRECHO_B  EXTENSAO_TRECHO_A_ATE_B  TIPO_TRECHO  STOP_CODE  \
# 0                   5015                     5,86            T     105807
# 1                   5012                    5,854            T     108209
# 2                   5014                    5,086            T     108207
# 3                   5013                    6,109            T     105810
# 4                   2286                    2,074            T     105729
# ...                  ...                      ...          ...        ...
# 1414                3522                   12,799            T     105716
# 1415                6491                   22,946            T     102033
# 1416                4517                   11,471            E     102033
# 1417                2176                    6,714            T     109058
# 1418                6665                    8,095            T     109034
#
#                                               STOP_NAME CODIGO_URBS  \
# 0          Terminal Portão - 616 - Portão / Linha Verde        1192
# 1                                        Estação Fanny.        1193
# 2                             Estação  Santa Bernadethe        1191
# 3     Terminal Portão - 616 - Portão / Santa Bernadethe        1190
# 4        Terminal Pinheirinho - 631 - Piratini / BR 476         872
# ...                                                 ...         ...
# 1414             Terminal Pinheirinho - 642 - Ganchinho         869
# 1415                Praça Rui Barbosa - 670 - São Jorge         672
# 1416                Praça Rui Barbosa - 670 - São Jorge         672
# 1417                            Estação Tubo Prefeitura         511
# 1418                   Estação Tubo Jardim das Américas         361
#
#             date
# 0     2023-11-25
# 1     2023-11-25
# 2     2023-11-25
# 3     2023-11-25
# 4     2023-11-25
# ...          ...
# 1414  2023-11-25
# 1415  2023-11-25
# 1416  2023-11-25
# 1417  2023-11-25
# 1418  2023-11-25
#
# [1419 rows x 23 columns]
